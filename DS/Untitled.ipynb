# %%
import pandas as pd

# %%
keywords = pd.read_csv('category_keywords.csv')

# %%
keywords
# Out:
#    Unnamed: 0                            0                             1  \
# 0           0  ('데일리', 24.935294024485227)   ('비수기', 12.057179996312124)
# 1           1      ('코', 1.20964809699917)      ('취소', 1.20964809699917)
# 2           2   ('이쁘다', 20.41925190697371)    ('태그해', 18.40205464368321)
# 3           3    ('국내', 37.78431356833906)     ('기록', 34.84267686956896)
# 4           4    ('한옥', 56.51945545236883)     ('마당', 7.403442834557912)
# 5           5   ('가득', 13.066737423740788)  ('인테리어', 12.166679787734356)
# 6           6  ('바라보다', 22.47114557286466)     ('바다', 20.28177819965627)
# 7           7   ('수영장', 7.224090075581868)    ('야외', 5.6053399526928285)
# 8           8    ('호캉', 19.96676123328397)    ('계획', 19.374903059527135)
# 9           9     ('바다', 30.1050026124984)   ('오션뷰', 25.960386458742136)
#
#                              2                             3  \
# 0    ('민박', 8.752228407502203)     ('카페', 8.499622505331669)
# ...

# %%
keywords.iloc[9, :]
# Out:
# Unnamed: 0                               9
# 0                 ('바다', 30.1050026124984)
# 1              ('오션뷰', 25.960386458742136)
# 2              ('수영장', 18.612956282823745)
# 3             ('바라보다', 12.182121454063763)
# 4              ('바베큐', 11.840513982884154)
# 5                ('호캉', 9.417858798694747)
# 6               ('멋지다', 9.119443299527658)
# 7                 ('계획', 8.55128852730715)
# 8                ('카페', 8.305664958802879)
# 9                ('힐링', 8.033348626646285)
# 10                ('일출', 8.00701456521179)
# 11                 ('야외', 8.0052033021571)
# 12                ('노을', 7.95240707435879)
# 13              ('가족', 7.8797026477092365)
# 14             ('프라이빗', 7.846586882313262)
# 15             ('아름답다', 7.844886555789189)
# 16               ('개별', 7.003063615537254)
# 17             ('인피니티', 6.857005568034965)
# 18               ('넓다', 6.775226734372409)
# 19               ('하늘', 6.632056306853087)
# Name: 9, dtype: object
